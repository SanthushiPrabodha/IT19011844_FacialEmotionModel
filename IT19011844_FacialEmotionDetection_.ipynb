# %% [markdown]
# <a href="https://colab.research.google.com/github/SanthushiPrabodha/IT19011844_FacialEmotionModel/blob/main/IT19011844_FacialEmotionDetection_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])
  ))
# Out:
#      <input type="file" id="files-7936eae8-ef28-4751-b8d5-f3ea646c2055" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7936eae8-ef28-4751-b8d5-f3ea646c2055">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving archive.zip to archive.zip
# User uploaded file "archive.zip" with length 63252113 bytes

# %%
from zipfile import ZipFile
file_name = "FacialEmotionDataset.zip"
with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print("Done")
# Out:
# Done

# %%
import numpy as np
import cv2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = 'train'
val_dir = 'test'
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (48,48),
    batch_size = 64,
    color_mode = "grayscale",
    class_mode = 'categorical'
)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(48,48),
    batch_size=64,
    color_mode="grayscale",
    class_mode="categorical"
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
emotion_model = Sequential()
emotion_model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
emotion_model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))
emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))
emotion_model.add(Flatten())
emotion_model.add(Dense(1024, activation='relu'))
emotion_model.add(Dropout(0.5))
emotion_model.add(Dense(7, activation='softmax'))

# %%
emotion_model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.0001, decay=1e-6),metrics=['accuracy'])
emotion_model_info = emotion_model.fit_generator(
        train_generator,
        steps_per_epoch=28709 // 64,
        epochs=50,
        validation_data=validation_generator,
        validation_steps=7178 // 64)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/50
# 448/448 [==============================] - 28s 41ms/step - loss: 1.8026 - accuracy: 0.2606 - val_loss: 1.7317 - val_accuracy: 0.3318
# Epoch 2/50
# 448/448 [==============================] - 20s 46ms/step - loss: 1.6515 - accuracy: 0.3550 - val_loss: 1.5685 - val_accuracy: 0.4046
# Epoch 3/50
# 448/448 [==============================] - 18s 40ms/step - loss: 1.5411 - accuracy: 0.4097 - val_loss: 1.4734 - val_accuracy: 0.4343
# Epoch 4/50
# 448/448 [==============================] - 18s 40ms/step - loss: 1.4671 - accuracy: 0.4394 - val_loss: 1.3992 - val_accuracy: 0.4711
# Epoch 5/50
# 448/448 [==============================] - 17s 39ms/step - loss: 1.4029 - accuracy: 0.4676 - val_loss: 1.3400 - val_accuracy: 0.4920
# Epoch 6/50
# 448/448 [==============================] - 17s 39ms/step - loss: 1.3521 - accuracy: 0.4876 - val_loss: 1.3017 - val_accuracy: 0.5070
# Epoch 7/50
# 448/448 [==============================] - 17s 39ms/step - loss: 1.3012 - accuracy: 0.5064 - val_loss: 1.2706 - val_accuracy: 0.5232
# Epoch 8/50
# 448/448 [==============================] - 17s 39ms/step - loss: 1.2634 - accuracy: 0.5225 - val_loss: 1.2446 - val_accuracy: 0.5297
# Epoch 9/50
# 448/448 [==============================] - 18s 39ms/step - loss: 1.2227 - accuracy: 0.5396 - val_loss: 1.2109 - val_accuracy: 0.5419
# Epoch 10/50
# 448/448 [==============================] - 18s 39ms/step - loss: 1.1942 - accuracy: 0.5510 - val_loss: 1.1966 - val_accuracy: 0.5477
# Epoch 11/50
# 448/448 [==============================] - 17s 39ms/step - loss: 1.1663 - accuracy: 0.5605 - val_loss: 1.1850 - val_accuracy: 0.5491
# Epoch 12/50
# 448/448 [==============================] - 18s 40ms/step - loss: 1.1348 - accuracy: 0.5738 - val_loss: 1.1513 - val_accuracy: 0.5626
# Epoch 13/50
# 448/448 [==============================] - 18s 39ms/step - loss: 1.1118 - accuracy: 0.5820 - val_loss: 1.1458 - val_accuracy: 0.5675
# Epoch 14/50
# 448/448 [==============================] - 18s 39ms/step - loss: 1.0833 - accuracy: 0.5987 - val_loss: 1.1219 - val_accuracy: 0.5785
# Epoch 15/50
# 448/448 [==============================] - 17s 39ms/step - loss: 1.0630 - accuracy: 0.6008 - val_loss: 1.1188 - val_accuracy: 0.5790
# Epoch 16/50
# 448/448 [==============================] - 17s 39ms/step - loss: 1.0341 - accuracy: 0.6140 - val_loss: 1.1123 - val_accuracy: 0.5783
# Epoch 17/50
# 448/448 [==============================] - 17s 39ms/step - loss: 1.0125 - accuracy: 0.6235 - val_loss: 1.1097 - val_accuracy: 0.5859
# Epoch 18/50
# 448/448 [==============================] - 18s 39ms/step - loss: 0.9824 - accuracy: 0.6376 - val_loss: 1.0993 - val_accuracy: 0.5905
# Epoch 19/50
# 448/448 [==============================] - 17s 38ms/step - loss: 0.9622 - accuracy: 0.6453 - val_loss: 1.0881 - val_accuracy: 0.5933
# Epoch 20/50
# 448/448 [==============================] - 17s 38ms/step - loss: 0.9374 - accuracy: 0.6548 - val_loss: 1.0971 - val_accuracy: 0.5942
# Epoch 21/50
# 448/448 [==============================] - 17s 38ms/step - loss: 0.9143 - accuracy: 0.6634 - val_loss: 1.0796 - val_accuracy: 0.5979
# Epoch 22/50
# 448/448 [==============================] - 17s 39ms/step - loss: 0.8942 - accuracy: 0.6721 - val_loss: 1.0667 - val_accuracy: 0.6069
# Epoch 23/50
# 448/448 [==============================] - 17s 39ms/step - loss: 0.8676 - accuracy: 0.6819 - val_loss: 1.0823 - val_accuracy: 0.6016
# Epoch 24/50
# 448/448 [==============================] - 17s 39ms/step - loss: 0.8477 - accuracy: 0.6875 - val_loss: 1.0729 - val_accuracy: 0.6097
# Epoch 25/50
# 448/448 [==============================] - 17s 38ms/step - loss: 0.8235 - accuracy: 0.6980 - val_loss: 1.0681 - val_accuracy: 0.6110
# Epoch 26/50
# 448/448 [==============================] - 17s 39ms/step - loss: 0.7995 - accuracy: 0.7061 - val_loss: 1.0742 - val_accuracy: 0.6087
# Epoch 27/50
# 448/448 [==============================] - 17s 39ms/step - loss: 0.7840 - accuracy: 0.7174 - val_loss: 1.0676 - val_accuracy: 0.6105
# Epoch 28/50
# 448/448 [==============================] - 18s 39ms/step - loss: 0.7507 - accuracy: 0.7254 - val_loss: 1.0690 - val_accuracy: 0.6176
# Epoch 29/50
# 448/448 [==============================] - 17s 39ms/step - loss: 0.7295 - accuracy: 0.7337 - val_loss: 1.0877 - val_accuracy: 0.6116
# Epoch 30/50
# 448/448 [==============================] - 17s 39ms/step - loss: 0.7109 - accuracy: 0.7427 - val_loss: 1.0905 - val_accuracy: 0.6091
# Epoch 31/50
# 448/448 [==============================] - 17s 39ms/step - loss: 0.6914 - accuracy: 0.7512 - val_loss: 1.0748 - val_accuracy: 0.6150
# Epoch 32/50
# 448/448 [==============================] - 17s 39ms/step - loss: 0.6652 - accuracy: 0.7580 - val_loss: 1.0787 - val_accuracy: 0.6226
# Epoch 33/50
# 448/448 [==============================] - 17s 39ms/step - loss: 0.6460 - accuracy: 0.7642 - val_loss: 1.0958 - val_accuracy: 0.6176
# Epoch 34/50
# 448/448 [==============================] - 17s 39ms/step - loss: 0.6231 - accuracy: 0.7747 - val_loss: 1.0903 - val_accuracy: 0.6240
# Epoch 35/50
# 448/448 [==============================] - 18s 40ms/step - loss: 0.6024 - accuracy: 0.7808 - val_loss: 1.1007 - val_accuracy: 0.6215
# Epoch 36/50
# 448/448 [==============================] - 18s 40ms/step - loss: 0.5864 - accuracy: 0.7846 - val_loss: 1.0947 - val_accuracy: 0.6246
# Epoch 37/50
# 448/448 [==============================] - 18s 40ms/step - loss: 0.5603 - accuracy: 0.7956 - val_loss: 1.1107 - val_accuracy: 0.6223
# Epoch 38/50
# 448/448 [==============================] - 18s 41ms/step - loss: 0.5456 - accuracy: 0.8016 - val_loss: 1.1165 - val_accuracy: 0.6254
# Epoch 39/50
# 448/448 [==============================] - 18s 41ms/step - loss: 0.5278 - accuracy: 0.8089 - val_loss: 1.1295 - val_accuracy: 0.6240
# Epoch 40/50
# 448/448 [==============================] - 18s 40ms/step - loss: 0.5119 - accuracy: 0.8160 - val_loss: 1.1364 - val_accuracy: 0.6198
# Epoch 41/50
# 448/448 [==============================] - 18s 40ms/step - loss: 0.4919 - accuracy: 0.8219 - val_loss: 1.1394 - val_accuracy: 0.6204
# Epoch 42/50
# 448/448 [==============================] - 18s 40ms/step - loss: 0.4724 - accuracy: 0.8293 - val_loss: 1.1423 - val_accuracy: 0.6267
# Epoch 43/50
# 448/448 [==============================] - 18s 40ms/step - loss: 0.4599 - accuracy: 0.8369 - val_loss: 1.1542 - val_accuracy: 0.6278
# Epoch 44/50
# 448/448 [==============================] - 18s 40ms/step - loss: 0.4434 - accuracy: 0.8396 - val_loss: 1.1772 - val_accuracy: 0.6243
# Epoch 45/50
# 448/448 [==============================] - 18s 39ms/step - loss: 0.4362 - accuracy: 0.8428 - val_loss: 1.1646 - val_accuracy: 0.6289
# Epoch 46/50
# 448/448 [==============================] - 18s 39ms/step - loss: 0.4142 - accuracy: 0.8512 - val_loss: 1.1759 - val_accuracy: 0.6286
# Epoch 47/50
# 448/448 [==============================] - 17s 39ms/step - loss: 0.4013 - accuracy: 0.8586 - val_loss: 1.1720 - val_accuracy: 0.6257
# Epoch 48/50
# 448/448 [==============================] - 18s 39ms/step - loss: 0.3911 - accuracy: 0.8569 - val_loss: 1.2039 - val_accuracy: 0.6286
# Epoch 49/50
# 448/448 [==============================] - 18s 40ms/step - loss: 0.3813 - accuracy: 0.8635 - val_loss: 1.2020 - val_accuracy: 0.6257
# Epoch 50/50
# 448/448 [==============================] - 18s 41ms/step - loss: 0.3678 - accuracy: 0.8674 - val_loss: 1.2088 - val_accuracy: 0.6279

# %%
#Saving the model
emotion_model.save('model.h5')

# %%
from tensorflow.keras.models import load_model
emotion_model = load_model('model.h5')

# %%
def emotion_analysis(emotions):
  objects = ('angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral')
  y_pos = np.arange(len(objects))

  plt.bar(y_pos, emotions, align='center', alpha=0.5)
  plt.xticks(y_pos, objects)
  plt.ylabel('percentage')
  plt.title('emotion')

  plt.show()

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='capture.jpg', quality=0.8):
  js = Javascript(''' 
      async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
take_photo()
# Out:
# 'capture.jpg'

# %%
import cv2
            
def facecrop(image):  
    facedata = '/content/haarcascade_frontalface_alt.xml'
    cascade = cv2.CascadeClassifier(facedata)

    img = cv2.imread(image)

    try:
    
        minisize = (img.shape[1],img.shape[0])
        miniframe = cv2.resize(img, minisize)

        faces = cascade.detectMultiScale(miniframe)

        for f in faces:
            x, y, w, h = [ v for v in f ]
            cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)

            sub_face = img[y:y+h, x:x+w]

            
            cv2.imwrite('photo.jpg', sub_face)
            #print ("Writing: " + image)

    except Exception as e:
        print (e)

if __name__ == '__main__':
    facecrop('/content/photo.jpg')

#Testing a file.

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt


file = '/content/capture.jpg'
true_image = image.load_img(file)
img = image.load_img(file, color_mode="grayscale", target_size=(48, 48))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom = emotion_model.predict(x)
emotion_analysis(custom[0])

x = np.array(x, 'float32')
x = x.reshape([48, 48]);

 
plt.imshow(true_image)
plt.show()
# Out:
# 'NoneType' object has no attribute 'shape'
