# %% [markdown]
# <a href="https://colab.research.google.com/github/SanthushiPrabodha/IT19011844_FacialEmotionModel/blob/main/IT19011844_FacialEmotionDetection_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])
  ))
# Out:
#      <input type="file" id="files-dc01f4ce-f253-423e-80aa-b3a73f26680f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dc01f4ce-f253-423e-80aa-b3a73f26680f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving FacialEmotionDataset.zip to FacialEmotionDataset.zip
# User uploaded file "FacialEmotionDataset.zip" with length 63252113 bytes

# %%
from zipfile import ZipFile
file_name = "FacialEmotionDataset.zip"
with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print("Done")
# Out:
# Done

# %%
import numpy as np
import cv2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = 'train'
val_dir = 'test'
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (48,48),
    batch_size = 64,
    color_mode = "grayscale",
    class_mode = 'categorical'
)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(48,48),
    batch_size=64,
    color_mode="grayscale",
    class_mode="categorical"
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
emotion_model = Sequential()
emotion_model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
emotion_model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))
emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))
emotion_model.add(Flatten())
emotion_model.add(Dense(1024, activation='relu'))
emotion_model.add(Dropout(0.5))
emotion_model.add(Dense(7, activation='softmax'))

# %%
emotion_model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.0001, decay=1e-6),metrics=['accuracy'])
emotion_model_info = emotion_model.fit_generator(
        train_generator,
        steps_per_epoch=28709 // 64,
        epochs=50,
        validation_data=validation_generator,
        validation_steps=7178 // 64)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# 448/448 [==============================] - 22s 26ms/step - loss: 1.8023 - accuracy: 0.2590 - val_loss: 1.7051 - val_accuracy: 0.3458
# Epoch 2/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.6245 - accuracy: 0.3663 - val_loss: 1.5357 - val_accuracy: 0.4149
# Epoch 3/50
# 448/448 [==============================] - 12s 26ms/step - loss: 1.5225 - accuracy: 0.4122 - val_loss: 1.4549 - val_accuracy: 0.4442
# Epoch 4/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.4482 - accuracy: 0.4455 - val_loss: 1.3962 - val_accuracy: 0.4692
# Epoch 5/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.3890 - accuracy: 0.4707 - val_loss: 1.3428 - val_accuracy: 0.4898
# Epoch 6/50
# 448/448 [==============================] - 12s 26ms/step - loss: 1.3376 - accuracy: 0.4930 - val_loss: 1.2989 - val_accuracy: 0.5031
# Epoch 7/50
# 448/448 [==============================] - 12s 26ms/step - loss: 1.2970 - accuracy: 0.5071 - val_loss: 1.2625 - val_accuracy: 0.5226
# Epoch 8/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.2558 - accuracy: 0.5254 - val_loss: 1.2402 - val_accuracy: 0.5273
# Epoch 9/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.2206 - accuracy: 0.5429 - val_loss: 1.2174 - val_accuracy: 0.5339
# Epoch 10/50
# 448/448 [==============================] - 12s 26ms/step - loss: 1.1848 - accuracy: 0.5562 - val_loss: 1.1965 - val_accuracy: 0.5494
# Epoch 11/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.1570 - accuracy: 0.5645 - val_loss: 1.1676 - val_accuracy: 0.5610
# Epoch 12/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.1341 - accuracy: 0.5754 - val_loss: 1.1674 - val_accuracy: 0.5571
# Epoch 13/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.1042 - accuracy: 0.5879 - val_loss: 1.1433 - val_accuracy: 0.5711
# Epoch 14/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.0822 - accuracy: 0.5951 - val_loss: 1.1334 - val_accuracy: 0.5709
# Epoch 15/50
# 448/448 [==============================] - 12s 26ms/step - loss: 1.0615 - accuracy: 0.6030 - val_loss: 1.1199 - val_accuracy: 0.5797
# Epoch 16/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.0319 - accuracy: 0.6155 - val_loss: 1.1121 - val_accuracy: 0.5791
# Epoch 17/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.0129 - accuracy: 0.6233 - val_loss: 1.1103 - val_accuracy: 0.5884
# Epoch 18/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.9876 - accuracy: 0.6339 - val_loss: 1.0923 - val_accuracy: 0.5883
# Epoch 19/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.9639 - accuracy: 0.6441 - val_loss: 1.0934 - val_accuracy: 0.5882
# Epoch 20/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.9379 - accuracy: 0.6527 - val_loss: 1.0880 - val_accuracy: 0.5944
# Epoch 21/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.9222 - accuracy: 0.6606 - val_loss: 1.0895 - val_accuracy: 0.5900
# Epoch 22/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.8961 - accuracy: 0.6694 - val_loss: 1.0827 - val_accuracy: 0.5911
# Epoch 23/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.8742 - accuracy: 0.6799 - val_loss: 1.0780 - val_accuracy: 0.6023
# Epoch 24/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.8525 - accuracy: 0.6883 - val_loss: 1.0782 - val_accuracy: 0.6035
# Epoch 25/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.8249 - accuracy: 0.6988 - val_loss: 1.0726 - val_accuracy: 0.6098
# Epoch 26/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.8051 - accuracy: 0.7041 - val_loss: 1.0710 - val_accuracy: 0.6097
# Epoch 27/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.7794 - accuracy: 0.7142 - val_loss: 1.0616 - val_accuracy: 0.6151
# Epoch 28/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.7598 - accuracy: 0.7217 - val_loss: 1.0611 - val_accuracy: 0.6151
# Epoch 29/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.7323 - accuracy: 0.7302 - val_loss: 1.0845 - val_accuracy: 0.6057
# Epoch 30/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.7104 - accuracy: 0.7424 - val_loss: 1.0756 - val_accuracy: 0.6166
# Epoch 31/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.6890 - accuracy: 0.7500 - val_loss: 1.0617 - val_accuracy: 0.6215
# Epoch 32/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.6719 - accuracy: 0.7554 - val_loss: 1.0813 - val_accuracy: 0.6129
# Epoch 33/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.6530 - accuracy: 0.7615 - val_loss: 1.0688 - val_accuracy: 0.6229
# Epoch 34/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.6252 - accuracy: 0.7711 - val_loss: 1.0832 - val_accuracy: 0.6222
# Epoch 35/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.6079 - accuracy: 0.7777 - val_loss: 1.0856 - val_accuracy: 0.6158
# Epoch 36/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.5849 - accuracy: 0.7893 - val_loss: 1.1253 - val_accuracy: 0.6208
# Epoch 37/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.5658 - accuracy: 0.7953 - val_loss: 1.1000 - val_accuracy: 0.6254
# Epoch 38/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.5516 - accuracy: 0.7994 - val_loss: 1.0973 - val_accuracy: 0.6219
# Epoch 39/50
# 448/448 [==============================] - 12s 27ms/step - loss: 0.5305 - accuracy: 0.8093 - val_loss: 1.1203 - val_accuracy: 0.6218
# Epoch 40/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.5105 - accuracy: 0.8152 - val_loss: 1.1401 - val_accuracy: 0.6194
# Epoch 41/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.5032 - accuracy: 0.8170 - val_loss: 1.1313 - val_accuracy: 0.6225
# Epoch 42/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.4805 - accuracy: 0.8280 - val_loss: 1.1416 - val_accuracy: 0.6247
# Epoch 43/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.4662 - accuracy: 0.8314 - val_loss: 1.1395 - val_accuracy: 0.6247
# Epoch 44/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.4558 - accuracy: 0.8358 - val_loss: 1.1550 - val_accuracy: 0.6271
# Epoch 45/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.4383 - accuracy: 0.8430 - val_loss: 1.1702 - val_accuracy: 0.6253
# Epoch 46/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.4285 - accuracy: 0.8449 - val_loss: 1.1610 - val_accuracy: 0.6279
# Epoch 47/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.4144 - accuracy: 0.8492 - val_loss: 1.1621 - val_accuracy: 0.6302
# Epoch 48/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.4038 - accuracy: 0.8533 - val_loss: 1.1778 - val_accuracy: 0.6320
# Epoch 49/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.3858 - accuracy: 0.8601 - val_loss: 1.1754 - val_accuracy: 0.6332
# Epoch 50/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.3762 - accuracy: 0.8653 - val_loss: 1.1842 - val_accuracy: 0.6292

# %%
#Saving the model
emotion_model.save('model.h5')

# %%
from tensorflow.keras.models import load_model
emotion_model = load_model('model.h5')

# %%
def emotion_analysis(emotions):
  objects = ('angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral')
  y_pos = np.arange(len(objects))

  plt.bar(y_pos, emotions, align='center', alpha=0.5)
  plt.xticks(y_pos, objects)
  plt.ylabel('percentage')
  plt.title('emotion')

  plt.show()

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='capture.jpg', quality=0.8):
  js = Javascript(''' 
      async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
take_photo()
# Out:
# 'capture.jpg'

# %%
import cv2
            
def facecrop(image):  
    facedata = '/content/haarcascade_frontalface_alt.xml'
    cascade = cv2.CascadeClassifier(facedata)

    img = cv2.imread(image)

    try:
    
        minisize = (img.shape[1],img.shape[0])
        miniframe = cv2.resize(img, minisize)

        faces = cascade.detectMultiScale(miniframe)

        for f in faces:
            x, y, w, h = [ v for v in f ]
            cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)

            sub_face = img[y:y+h, x:x+w]

            
            cv2.imwrite('photo.jpg', sub_face)
            #print ("Writing: " + image)

    except Exception as e:
        print (e)

if __name__ == '__main__':
    facecrop('/content/photo.jpg')

#Testing a file.

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt


file = '/content/capture.jpg'
true_image = image.load_img(file)
img = image.load_img(file, color_mode="grayscale", target_size=(48, 48))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom = emotion_model.predict(x)
emotion_analysis(custom[0])

x = np.array(x, 'float32')
x = x.reshape([48, 48]);

 
plt.imshow(true_image)
plt.show()
# Out:
# 'NoneType' object has no attribute 'shape'
